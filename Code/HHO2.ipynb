# %%
import pickle

# Load features_reshaped from the pickle file
with open('features_reshaped.pkl', 'rb') as f:
    features_reshaped_m = pickle.load(f)

# %%
import pickle

# Load features_reshaped from the pickle file
with open('features_reshaped.pkl', 'rb') as f:
    features_reshaped_s = pickle.load(f)

# %%
import numpy as np
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from solution import solution  # Import HHO implementation

# %%
# Step 2: Combine Features
combined_features = np.concatenate((features_reshaped_m, features_reshaped_s), axis=1)

# %%
# Print the number of features
num_features = combined_features.shape[1]
print("Number of features:", num_features)
# Out:
# Number of features: 3136

# %%
from sklearn.decomposition import PCA

# Create a PCA instance with desired number of components (2000 in this case)
pca = PCA(n_components=2000)

# Fit PCA on your combined feature set
pca.fit(combined_features)

# Transform the data to its lower-dimensional representation
reduced_features = pca.transform(combined_features)

# Now reduced_features contains the reduced-dimensional representation of your original feature set

# %%
from sklearn.decomposition import PCA

# Define the desired number of components for PCA
n_components = 500  # Adjust this number as needed

# Create a PCA instance with the desired number of components
pca = PCA(n_components=n_components)

# Fit PCA on your combined feature set
pca.fit(combined_features)

# Transform the data to its lower-dimensional representation
reduced_features = pca.transform(combined_features)

# Now reduced_features contains the reduced-dimensional representation of your original feature set

# %%
# Directory path containing QR code images
qr_code_path = 'qr_codes2'

labels = np.array([1] * 1000 + [2] * 1000 + [3] * 1000 + [4] * 1000 + [5] * 1000 + [6] * 1000)

# Subtract 1 to bring labels into the range [0, 5]
labels = labels - 1

# %%
from sklearn.preprocessing import StandardScaler

# Scale the reduced_features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(reduced_features)

# Use scaled_features for training logistic regression classifier
# Adjust other parts of your code accordingly

# %%
# Step 3: Feature Selection with HHO
def objective_function(selected_features):
    # Threshold the selected_features to be binary (0 or 1)
    selected_features = np.where(selected_features > 0.5, 1, 0)
    
    # Pass selected features through SVM classifier
    #svm_classifier = SVC(kernel='linear')
    #svm_classifier.fit(reduced_features[:, selected_features], labels)  # Assuming labels are defined
    
    # Evaluate SVM classifier on the test set (if needed)
    # svm_accuracy = svm_classifier.score(X_test[:, selected_features], y_test)
    
    # Pass selected features through KNN classifier
    knn_classifier = KNeighborsClassifier(n_neighbors=5)
    knn_classifier.fit(reduced_features[:, selected_features], labels)  # Assuming labels are defined
    
    # Evaluate KNN classifier on the test set (if needed)
    # knn_accuracy = knn_classifier.score(X_test[:, selected_features], y_test)
    
    # Calculate fitness as the average accuracy of SVM and KNN classifiers
    #fitness = (svm_classifier.score(reduced_features[:, selected_features], labels) + knn_classifier.score(reduced_features[:, selected_features], labels)) / 2
    
    fitness =  knn_classifier.score(reduced_features[:, selected_features], labels)
    
    return -fitness  # Return negative accuracy for minimization (HHO maximizes the objective function)

# Run HHO algorithm for feature selection
import HHO
selected_features = HHO.HHO(objective_function, lb=-100, ub=100, SearchAgents_no=50, Max_iter=100, dim=reduced_features.shape[1])
# Out:
# HHO is now tackling  "objective_function"
# ['At iteration 0 the best fitness is -0.6126666666666667']
# ['At iteration 1 the best fitness is -0.613']
# ['At iteration 2 the best fitness is -0.613']
# ['At iteration 3 the best fitness is -0.615']
# ['At iteration 4 the best fitness is -0.615']
# ['At iteration 5 the best fitness is -0.615']
# ['At iteration 6 the best fitness is -0.615']
# ['At iteration 7 the best fitness is -0.615']
# ['At iteration 8 the best fitness is -0.615']
# ['At iteration 9 the best fitness is -0.615']
# ['At iteration 10 the best fitness is -0.615']
# ['At iteration 11 the best fitness is -0.615']
# ['At iteration 12 the best fitness is -0.615']
# ['At iteration 13 the best fitness is -0.615']
# ['At iteration 14 the best fitness is -0.615']
# ['At iteration 15 the best fitness is -0.615']
# ['At iteration 16 the best fitness is -0.615']
# ['At iteration 17 the best fitness is -0.615']
# ['At iteration 18 the best fitness is -0.615']
# ...

# %%
# Step 3: Feature Selection with HHO
def objective_function(selected_features):
    # Threshold the selected_features to be binary (0 or 1)
    selected_features = np.where(selected_features > 0.5, 1, 0)
    
    # Pass selected features through SVM classifier
    #svm_classifier = SVC(kernel='linear')
    #svm_classifier.fit(reduced_features[:, selected_features], labels)  # Assuming labels are defined
    
    # Evaluate SVM classifier on the test set (if needed)
    # svm_accuracy = svm_classifier.score(X_test[:, selected_features], y_test)
    
    # Pass selected features through KNN classifier
    knn_classifier = KNeighborsClassifier(n_neighbors=5)
    knn_classifier.fit(reduced_features[:, selected_features], labels)  # Assuming labels are defined
    
    # Evaluate KNN classifier on the test set (if needed)
    # knn_accuracy = knn_classifier.score(X_test[:, selected_features], y_test)
    
    # Calculate fitness as the average accuracy of SVM and KNN classifiers
    #fitness = (svm_classifier.score(reduced_features[:, selected_features], labels) + knn_classifier.score(reduced_features[:, selected_features], labels)) / 2
    
    fitness =  knn_classifier.score(reduced_features[:, selected_features], labels)
    
    return -fitness  # Return negative accuracy for minimization (HHO maximizes the objective function)

# Run HHO algorithm for feature selection
import HHO
selected_features = HHO.HHO(objective_function, lb=-100, ub=100, SearchAgents_no=50, Max_iter=100, dim=reduced_features.shape[1])
# Out:
# HHO is now tackling  "objective_function"
# ['At iteration 0 the best fitness is -0.611']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 29
#      27 # Run HHO algorithm for feature selection
#      28 import HHO
# ---> 29 selected_features = HHO.HHO(objective_function, lb=-100, ub=100, SearchAgents_no=50, Max_iter=100, dim=reduced_features.shape[1])
#
# File c:\Users\ilfas\OneDrive\Documents\college\design project\implementation\HHO.py:62, in HHO(objf, lb, ub, dim, SearchAgents_no, Max_iter)
#      59 X[i,:]=numpy.clip(X[i,:], lb, ub)
#      61 # fitness of locations
# ---> 62 fitness=objf(X[i,:])
#      64 # Update the location of Rabbit
#      65 if fitness<Rabbit_Energy: # Change this to > for maximization problem
#
# Cell In[55], line 23, in objective_function(selected_features)
# ...

# %%
import pickle

# Save features_reshaped to a file using pickle
with open('selected_features.pkl', 'wb') as f:
    pickle.dump(selected_features, f)

# %%
with open('selected_features.pkl', 'rb') as f:
    selected_features = pickle.load(f)

# %%
from sklearn.model_selection import train_test_split
# Split the extracted features into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(reduced_features, labels, test_size=0.3, random_state=42)

# %%
import numpy as np

# Convert selected_features to an array of integers
selected_features_indices = np.where(selected_features)[0]

# Split the data into training and testing sets using the valid indices
X_train, X_test = reduced_features[selected_features_indices], reduced_features[selected_features_indices]
# Out:
# C:\Users\ilfas\AppData\Local\Temp\ipykernel_50920\2468440442.py:4: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(arr).nonzero()` if the old behavior was intended.
#   selected_features_indices = np.where(selected_features)[0]

# %%
# Split the labels into training and testing sets using the valid indices
y_train, y_test = labels[selected_features_indices], labels[selected_features_indices]

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
# Convert selected_features to an array of integers
selected_features_indices = np.where(selected_features)[0]

# Pass Selected Features through SVM and KNN
selected_features_svm = X_train[:, selected_features_indices]
selected_features_knn = X_train[:, selected_features_indices]
# Out:
# C:\Users\ilfas\AppData\Local\Temp\ipykernel_6920\2783381833.py:2: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(arr).nonzero()` if the old behavior was intended.
#   selected_features_indices = np.where(selected_features)[0]

# %%
# Train SVM classifier using selected features
svm_classifier_selected = SVC(kernel='linear')
svm_classifier_selected.fit(selected_features_svm, y_train)
# Out:
# SVC(kernel='linear')

# %%
selected_features_svm_test = X_test[:, selected_features_indices]

# %%
# Evaluate SVM classifier on the testing set
svm_accuracy = svm_classifier_selected.score(selected_features_svm_test, y_test)
print("SVM Classifier Accuracy:", 1-svm_accuracy)
# Out:
# SVM Classifier Accuracy: 0.6405555555555555

# %%
# Train SVM classifier using selected features
svm_classifier_selected = SVC(kernel='poly', degree=2, C=1.0, gamma='auto')
svm_classifier_selected.fit(selected_features_svm, y_train)
# Out:
# SVC(degree=2, gamma='auto', kernel='poly')

# %%
# Evaluate SVM classifier on the testing set
svm_accuracy = svm_classifier_selected.score(selected_features_svm_test, y_test)
print("SVM Classifier Accuracy:", 1-svm_accuracy)
# Out:
# SVM Classifier Accuracy: 0.6405555555555555

# %%
selected_features_knn_test = X_test[:, selected_features_indices]

# %%
# Train KNN classifier using selected features
knn_classifier_selected = KNeighborsClassifier(metric='euclidean')
knn_classifier_selected.fit(selected_features_knn, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
# Evaluate KNN classifier on the testing set
knn_accuracy = knn_classifier_selected.score(selected_features_knn_test, y_test)
print("KNN Classifier Accuracy:", 1-knn_accuracy)
# Out:
# KNN Classifier Accuracy: 0.6233333333333333

# %%
# Train KNN classifier using selected features
knn_classifier = KNeighborsClassifier(metric='manhattan')
knn_classifier_selected.fit(selected_features_knn, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
# Evaluate KNN classifier on the testing set
knn_accuracy = knn_classifier_selected.score(selected_features_knn_test, y_test)
print("KNN Classifier Accuracy:", 1-knn_accuracy)
# Out:
# KNN Classifier Accuracy: 0.6233333333333333

# %%
# Train KNN classifier using selected features
knn_classifier = KNeighborsClassifier(metric='minkowski')
knn_classifier_selected.fit(selected_features_knn, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
# Evaluate KNN classifier on the testing set
knn_accuracy = knn_classifier_selected.score(selected_features_knn_test, y_test)
print("KNN Classifier Accuracy:", 1-knn_accuracy)
# Out:
# KNN Classifier Accuracy: 0.6233333333333333
